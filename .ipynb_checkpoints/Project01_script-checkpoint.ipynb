# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import fuzzywuzzy
import re
from collections import Counter
import seaborn as sns
import math

# %%
df = pd.read_csv("airplane_crashes_and_fatalities_since_1908.csv")

# %%
#Clean up time 
df["Time"] = df["Time"].replace(np.nan, "Unknown") 
df["Time"] = df["Time"].str.replace("114:20:00", "Unknown")
df["Time"] = df["Time"].str.replace("18.40", "18:40")
df["Time"] = df["Time"].str.replace("0943", "09:43")
df["Time"] = df["Time"].str.replace("12\'20", "12:20")
df["Time"] = df["Time"].str.replace("22\'08", "22:08")
df["Time"] = df["Time"].str.replace("c: ", "")
df["Time"] = df["Time"].str.replace("c:", "")
df["Time"] = df["Time"].str.replace("c", "")

#Match upper/lower case formats
df = df.applymap(lambda s:s.upper() if type(s) == str else s)

#Create new columns for month, day, year, hour, and minute
    
df['Date']=pd.to_datetime(df['Date'])
df['Day'] = df['Date'].map(lambda x: x.day)
df['Year'] = df['Date'].map(lambda x: x.year)
df['Month'] = df['Date'].map(lambda x: x.month)

# %% [markdown]
# # Drop NaN values

# %%
df1 = df[['Year', 'Operator', 'Aboard', 'Fatalities', 'Summary']].dropna(subset=['Operator', 'Aboard', 'Fatalities', 'Summary'])
df1.head(5)
# Out:
#    Year                Operator  Aboard  Fatalities  \
# 0  1908    MILITARY - U.S. ARMY     2.0         1.0
# 1  1912    MILITARY - U.S. NAVY     5.0         5.0
# 2  1913                 PRIVATE     1.0         1.0
# 3  1913  MILITARY - GERMAN NAVY    20.0        14.0
# 4  1913  MILITARY - GERMAN NAVY    30.0        30.0
#
#                                              Summary
# 0  DURING A DEMONSTRATION FLIGHT, A U.S. ARMY FLY...
# 1  FIRST U.S. DIRIGIBLE AKRON EXPLODED JUST OFFSH...
# 2  THE FIRST FATAL AIRPLANE ACCIDENT IN CANADA OC...
# 3  THE AIRSHIP FLEW INTO A THUNDERSTORM AND ENCOU...
# 4  HYDROGEN GAS WHICH WAS BEING VENTED WAS SUCKED...

# %% [markdown]
# # Military DataFrame

# %%
df_military = df1[df1["Operator"].str.contains("MILITARY")]
df_military
# Out:
#       Year                                           Operator  Aboard  \
# 0     1908                               MILITARY - U.S. ARMY     2.0
# 1     1912                               MILITARY - U.S. NAVY     5.0
# 3     1913                             MILITARY - GERMAN NAVY    20.0
# 4     1913                             MILITARY - GERMAN NAVY    30.0
# 5     1915                             MILITARY - GERMAN NAVY    41.0
# 6     1915                             MILITARY - GERMAN NAVY    19.0
# 7     1916                             MILITARY - GERMAN ARMY    20.0
# 8     1916                             MILITARY - GERMAN NAVY    22.0
# 9     1916                             MILITARY - GERMAN NAVY    19.0
# 10    1916                             MILITARY - GERMAN ARMY    28.0
# 11    1916                             MILITARY - GERMAN NAVY    20.0
# 12    1917                             MILITARY - GERMAN ARMY    20.0
# 13    1917                             MILITARY - GERMAN NAVY    23.0
# 14    1917                             MILITARY - GERMAN NAVY    21.0
# 15    1917                             MILITARY - GERMAN NAVY    24.0
# 16    1917                             MILITARY - GERMAN NAVY    18.0
# 17    1917                             MILITARY - GERMAN NAVY    18.0
# 18    1918                             MILITARY - GERMAN NAVY    23.0
# 19    1918                             MILITARY - GERMAN NAVY    22.0
# 20    1918                             MILITARY - GERMAN NAVY    19.0
# 6           19.0  EXPLODED AND BURNED NEAR NEUWERK ISLAND,  WHEN...
# 7           20.0         CRASHED NEAR THE BLACK SEA, CAUSE UNKNOWN.
# 8           22.0  SHOT DOWN BY BRITISH AIRCRAFT CRASHING IN FLAMES.
# 9           19.0  SHOT DOWN IN FLAMES BY THE BRITISH 39TH HOME D...
# 10          27.0                                CRASHED IN A STORM.
# 11          20.0  SHOT DOWN BY BRITISH ANTI-AIRCRAFT FIRE AND AI...
# 12          20.0                           CAUGHT FIRE AND CRASHED.
# 13          23.0  STRUCK BY LIGHTNING AND CRASHED INTO THE BALTI...
# 14          21.0  CRASHED INTO THE SEA FROM AN ALTITUDE OF 3,000...
# 15          24.0                     SHOT DOWN BY BRITISH AIRCRAFT.
# 16          18.0                     SHOT DOWN BY BRITISH AIRCRAFT.
# 17          18.0            SHOT DOWN BY FRENCH ANTI-AIRCRAFT FIRE.
# 18          23.0  EXPLODED AND CRASHED INTO THE SEA OFF THE SOUT...
# 19          22.0  SHOT DOWN BY BRITISH AIRCRAFT CRASHING FROM A ...
# 20          19.0                     SHOT DOWN BY BRITISH AIRCRAFT.
# 55          46.0  CRASHED DUE TO STRUCTURAL FAILURE FOLLOWED BY ...
# 59          34.0  CRASHED FROM A HEIGHT OF 500 FT. AFTER EXPERIE...
# 80          52.0  CRASHED WHILE ON A FLIGHT FROM TOULON, FRANCE ...
# 96          14.0  THE SHENANDOAH WAS FLYING OVER SOUTHERN OHIO W...
# 176          6.0  A MIDAIR COLLISION OCCURRED  WITH A US AIR FOR...
# 221         48.0  THE AIRSHIP WAS ON ITS INAUGURAL FLIGHT FROM C...
# 299         73.0  WHILE CRUISING AT 1,600 FEET OFF NEW JERSEY, S...
# 457         11.0  THE TWO AIRCRAFT CRASHED IN MID-AIR IN HEAVY R...
# 478          1.0  ONE AIRCRAFT FROM A SQUADRON PERFORMING AEROBA...
# 518          1.0  WHILE PERFORMING AEROBATICS, THE AIRCRAFT LOST...
# ...          ...                                                ...
# 5053        13.0  THE PLANE WAS ON ITS ROUTINE OPERATIONS OF DEL...
# 5073        94.0  THE MILITARY PLANE CRASHED INTO AN APARTMENT B...
# 5082        11.0  AFTER A FLYBY TO CHECK ON A STUCK LANDING GEAR...
# 5083        42.0  A PLANE CARRYING PEACEKEEPING SOLDIERS CRASHED...
# 5088         6.0  WHILE EN ROUTE, THE PLANE, DELIVERING HUMANITA...
# 5092        14.0  WHILE ON APPROACH THE AIRPLANE FLEW INTO THE S...
# 5093         6.0  UPON ARRIVAL OF THE CARGO FLIGHT, THE CREW IND...
# 5101        40.0  WITNESSES SAID THEY HEARD AN EXPLOSION AND WHE...
# 5103         5.0  THE MILITARY PLANE CRASHED INTO TREES PAST THE...
# 5117        14.0  THE NATO SUPPORTING AIRCRAFT CRASHED 12 MILES ...
# 5118        12.0  ELEVEN HIGH RANKING OFFICERS WERE KILLED WHEN ...
# 5119        13.0  THE MILITARY PLANE CRASHED EN ROUTE LESS THAN ...
# 5122        15.0  THE PLANE BELONGING TO UZBEKISTAN AIRWAYS AND ...
# 5124        38.0  THE AIRCRAFT CRASHED AFTER LOSING THE RIGHT EN...
# 5133        12.0       THE HELICOPTER CRASHED NORTHEAST OF BAGHDAD.
# 5144        18.0  THE HELICOPTER WAS CARRYING OUT A MISSIION WIT...
# 5146         9.0  COLLIDED WITH A TRUCK WHILE ATTEMPTING TO MAKE...
# 5148        13.0  CRASHED INTO DENSE JUNGLE SHORTLY AFTER TAKING...
# 5166        14.0  CRASHED MOST LIKELY DUE TO A MECHANICAL PROBLE...
# 5170        11.0  THE HELICOPTER CRASHED 15 MILES SOUTHEAST OF S...
# 5188        20.0  WHILE ATTEMPTING TO LAND, THE PLANE FELL TO TH...
# 5198        13.0  CRASHED INTO THE OCEAN AFTER SKIDDING OFF THE ...
# 5205        11.0  CHILE'S NATIONAL POLICE CHIEF GENERAL JOSE ALE...
# 5211        10.0  THE MILITARY HELICOPTER DEVELOPED A MECHANICAL...
# 5212        18.0  THE PLANE WENT MISSING IN AN AREA APPROXIMATEL...
# 5222        10.0  THE HELICOPTER CRASHED WHILE FERRYING A FORENS...
# 5257        24.0  WHILE RETURNING FROM A MILITARY TRAINING EXERC...
# 5262        18.0  THE HELICOPTER WAS PATROLLING ALONG THE VENEZU...
# 5263        98.0  WHILE ON APPROACH, THE MILITARY TRANSPORT CRAS...
# 5267        13.0  THE MILITARY TRANSPORT WENT MISSING WHILE EN R...
#
# [731 rows x 5 columns]

# %%
m_fatalities_count = df_military.groupby(["Year"])['Fatalities'].sum()
m_totals_count = df_military.groupby(["Year"])['Aboard'].sum()
m_fatality_rate = m_fatalities_count / m_totals_count
m_fatalities_count.sum()/m_totals_count.sum()
# Out:
# 0.9159840062414667

# %%
df2_military = pd.DataFrame({"Fatality Rate": m_fatality_rate})
df2_military.head(10)
# Out:
#       Fatality Rate
# Year
# 1908       0.500000
# 1912       1.000000
# 1913       0.880000
# 1915       0.666667
# 1916       0.990826
# 1917       1.000000
# 1918       1.000000
# 1921       1.000000
# 1922       0.755556
# 1923       1.000000

# %%
military_chart = df2_military.plot(kind="line", color = "olive")
plt.savefig("Charts/m_fatal.png")

# %%
df2_military = pd.DataFrame({"Fatality Rate": m_fatality_rate})
df2_military = df2_military.reset_index()
df2_military.head(5)
# Out:
#    Year  Fatality Rate
# 0  1908       0.500000
# 1  1912       1.000000
# 2  1913       0.880000
# 3  1915       0.666667
# 4  1916       0.990826

# %%
sns.regplot(x = "Year" , y = "Fatality Rate", data = df2_military, color = "olive")
plt.savefig("Charts/m_regression.png")

# %% [markdown]
# # Commercial DataFrame

# %%
df_commercial = df1[df1["Operator"].str.contains("MILITARY") == False]

# %%
c_fatalities_count = df_commercial.groupby(["Year"])['Fatalities'].sum()
c_totals_count = df_commercial.groupby(["Year"])['Aboard'].sum()
c_fatality_rate = c_fatalities_count / c_totals_count
c_fatalities_count.sum()/c_totals_count.sum()
# Out:
# 0.6946674765157629

# %%
df2_commercial = pd.DataFrame({"Fatality Rate": c_fatality_rate})
commercial_chart = df2_commercial.plot(kind = "line")
plt.show()
plt.savefig("Charts/c_fatal.png")

# %%
df2_commercial = pd.DataFrame({"Fatality Rate": c_fatality_rate})
df2_commercial = df2_commercial.reset_index()

# %%
sns.regplot(x = "Year" , y = "Fatality Rate", data = df2_commercial)
plt.savefig("Charts/c_.png")
